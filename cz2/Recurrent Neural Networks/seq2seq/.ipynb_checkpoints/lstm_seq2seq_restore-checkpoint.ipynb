# %% [markdown]
# # Restore a character-level sequence to sequence model from to generate predictions.
#
# Source:
# https://keras.io/examples/lstm_seq2seq_restore/
#
# This script loads the s2s.h5 model saved by lstm_seq2seq.py and generates sequences from it. It assumes that no changes have been made (for example: latent_dim is unchanged, and the input data and model architecture are unchanged).

# %% [markdown]
# ### Data download
#
# Lots of neat sentence pairs datasets. http://www.manythings.org/anki/

# %%
from __future__ import print_function

from keras.models import Model, load_model
from keras.layers import Input
import numpy as np

batch_size = 64  # Batch size for training.
epochs = 100  # Number of epochs to train for.
latent_dim = 256  # Latent dimensionality of the encoding space.
num_samples = 10000  # Number of samples to train on.
# Path to the data txt file on disk.
data_path = '../lang_pairs/pol.txt'

# %% [markdown]
# Let's read the sentences (input = English, target = Polish),
# and extract the character sets for each language.
#
# Target sequences get additional "start sequence" and "end sequence" characters.

# %%
# Vectorize the data.  We use the same approach as the training script.
# NOTE: the data must be identical, in order for the character -> integer
# mappings to be consistent.
# We omit encoding target_texts since they are not needed.
input_texts = []
target_texts = []
input_characters = set()
target_characters = set()
with open(data_path, 'r', encoding='utf-8') as f:
    lines = f.read().split('\n')
for line in lines[: min(num_samples, len(lines) - 1)]:
    input_text, target_text, licence = line.split('\t')
    # We use "tab" as the "start sequence" character
    # for the targets, and "\n" as "end sequence" character.
    target_text = '\t' + target_text + '\n'
    input_texts.append(input_text)
    target_texts.append(target_text)
    for char in input_text:
        if char not in input_characters:
            input_characters.add(char)
    for char in target_text:
        if char not in target_characters:
            target_characters.add(char)

input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)
max_encoder_seq_length = max([len(txt) for txt in input_texts])
max_decoder_seq_length = max([len(txt) for txt in target_texts])

print('Number of samples:', len(input_texts))
print('Number of unique input tokens:', num_encoder_tokens)
print('Number of unique output tokens:', num_decoder_tokens)
print('Max sequence length for inputs:', max_encoder_seq_length)
print('Max sequence length for outputs:', max_decoder_seq_length)
# Out:
# Number of samples: 10000
# Number of unique input tokens: 71
# Number of unique output tokens: 90
# Max sequence length for inputs: 20
# Max sequence length for outputs: 58

# %% [markdown]
# Make character-to-index dictionaries
# and prepare one-hot-encoding of the whole training input data.
# Note that the sequences are zero-(post)padded to have all equal lengths.

# %%
input_token_index = dict(
    [(char, i) for i, char in enumerate(input_characters)])
target_token_index = dict(
    [(char, i) for i, char in enumerate(target_characters)])

encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length, num_encoder_tokens),
    dtype='float32')

for i, input_text in enumerate(input_texts):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.

# %%
# Restore the model and construct the encoder and decoder.
model = load_model('s2s.h5')

encoder_inputs = model.input[0]   # input_1
encoder_outputs, state_h_enc, state_c_enc = model.layers[2].output   # lstm_1
encoder_states = [state_h_enc, state_c_enc]
encoder_model = Model(encoder_inputs, encoder_states)

decoder_inputs = model.input[1]   # input_2
decoder_state_input_h = Input(shape=(latent_dim,), name='input_3')
decoder_state_input_c = Input(shape=(latent_dim,), name='input_4')
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_lstm = model.layers[3]
decoder_outputs, state_h_dec, state_c_dec = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs)
decoder_states = [state_h_dec, state_c_dec]
decoder_dense = model.layers[4]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs] + decoder_states)

# Reverse-lookup token index to decode sequences back to
# something readable.
reverse_input_char_index = dict(
    (i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict(
    (i, char) for char, i in target_token_index.items())

# %%
# Decodes an input sequence.  Future work should support beam search.
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0, target_token_index['\t']] = 1.

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict(
            [target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        if (sampled_char == '\n' or
           len(decoded_sentence) > max_decoder_seq_length):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.

        # Update states
        states_value = [h, c]

    return decoded_sentence

# %%
for seq_index in range(100):
    # Take one sequence (part of the training set)
    # for trying out decoding.
    input_seq = encoder_input_data[seq_index+1000: seq_index + 1001]
    decoded_sentence = decode_sequence(input_seq)
    print('-')
    print('Input sentence:', input_texts[seq_index+1000])
    print('Decoded sentence:', decoded_sentence)
# Out:
# -
# Input sentence: He is nice.
# Decoded sentence: Jest bieniem.
#
# -
# Input sentence: He is poor.
# Decoded sentence: Jest bardzo wysoki.
#
# -
# Input sentence: He is sick.
# Decoded sentence: wierzije chorej.
#
# -
# Input sentence: He is tall.
# Decoded sentence: Jest atworszy.
#
# -
# Input sentence: He made it.
# Decoded sentence: Nie mógł pływać.
#
# -
# Input sentence: He made it.
# Decoded sentence: Nie mógł pływać.
#
# -
# Input sentence: He's Swiss.
# Decoded sentence: On jest Amerykanana.
#
# -
# Input sentence: He's Swiss.
# Decoded sentence: On jest Amerykanana.
#
# -
# Input sentence: He's smart.
# Decoded sentence: On jest ten gartu.
#
# -
# Input sentence: Head north.
# Decoded sentence: Ziedział bego prawni.
#
# -
# Input sentence: Head south.
# Decoded sentence: Zwczyczyła skrotne.
#
# -
# Input sentence: Hello, Tom.
# Decoded sentence: Czętaj uszykój.
#
# -
# Input sentence: Here it is.
# Decoded sentence: Otu resztaw pracę.
#
# -
# Input sentence: Hey, relax.
# Decoded sentence: Marej ustawić.
#
# -
# Input sentence: Hold still.
# Decoded sentence: Wszystki ta kobi.
#
# -
# Input sentence: Hold still.
# Decoded sentence: Wszystki ta kobi.
#
# -
# Input sentence: Hold still.
# Decoded sentence: Wszystki ta kobi.
#
# -
# Input sentence: Hold still.
# Decoded sentence: Wszystki ta kobi.
#
# -
# Input sentence: Hold still.
# Decoded sentence: Wszystki ta kobi.
#
# -
# Input sentence: Hold still.
# Decoded sentence: Wszystki ta kobi.
#
# -
# Input sentence: Hold still.
# Decoded sentence: Wszystki ta kobi.
#
# -
# Input sentence: How absurd!
# Decoded sentence: Ale barbarzyste.
#
# -
# Input sentence: How absurd!
# Decoded sentence: Ale barbarzyste.
#
# -
# Input sentence: How absurd!
# Decoded sentence: Ale barbarzyste.
#
# -
# Input sentence: How absurd!
# Decoded sentence: Ale barbarzyste.
#
# -
# Input sentence: How clever!
# Decoded sentence: Bleż zekarzaw to.
#
# -
# Input sentence: How clever!
# Decoded sentence: Bleż zekarzaw to.
#
# -
# Input sentence: How clever!
# Decoded sentence: Bleż zekarzaw to.
#
# -
# Input sentence: How clever!
# Decoded sentence: Bleż zekarzaw to.
#
# -
# Input sentence: How lovely!
# Decoded sentence: Cóż za przeniasz!
#
# -
# Input sentence: How tragic!
# Decoded sentence: Cóż za twasz, że mogasz.
#
# -
# Input sentence: How was it?
# Decoded sentence: Jak się ma warsej?
#
# -
# Input sentence: Hurry back.
# Decoded sentence: Marzcie spał.
#
# -
# Input sentence: Hurry back.
# Decoded sentence: Marzcie spał.
#
# -
# Input sentence: Hurry back.
# Decoded sentence: Marzcie spał.
#
# -
# Input sentence: Hurry home.
# Decoded sentence: Skrowal suszą.
#
# -
# Input sentence: I admit it.
# Decoded sentence: Wysiałem z Tom'em.
#
# -
# Input sentence: I am a boy.
# Decoded sentence: Jestem nauczycielem.
#
# -
# Input sentence: I am a man.
# Decoded sentence: Jestem cierpiczanam.
#
# -
# Input sentence: I am a man.
# Decoded sentence: Jestem cierpiczanam.
#
# -
# Input sentence: I am happy.
# Decoded sentence: Jestem niesoczęszny.
#
# -
# Input sentence: I am human.
# Decoded sentence: Duję tutaj usty.
#
# -
# Input sentence: I am ready.
# Decoded sentence: Jubię rasy zasta.
#
# -
# Input sentence: I am right.
# Decoded sentence: Poszedłem nosko.
#
# -
# Input sentence: I am short.
# Decoded sentence: Jestem dzisprzej.
#
# -
# Input sentence: I am short.
# Decoded sentence: Jestem dzisprzej.
#
# -
# Input sentence: I am smart.
# Decoded sentence: Jestem spóźniony.
#
# -
# Input sentence: I beat Tom.
# Decoded sentence: Praweż tupaj myzyku.
#
# -
# Input sentence: I built it.
# Decoded sentence: uciełem z piałem.
#
# -
# Input sentence: I can jump.
# Decoded sentence: Umiem pomożam.
#
# -
# Input sentence: I can jump.
# Decoded sentence: Umiem pomożam.
#
# -
# Input sentence: I can swim.
# Decoded sentence: Może patrofić.
#
# -
# Input sentence: I can swim.
# Decoded sentence: Może patrofić.
#
# -
# Input sentence: I can wait.
# Decoded sentence: Dobrze mierazej.
#
# -
# Input sentence: I can walk.
# Decoded sentence: Moremiślu wygrać.
#
# -
# Input sentence: I can walk.
# Decoded sentence: Moremiślu wygrać.
#
# -
# Input sentence: I canceled.
# Decoded sentence: Zdzierłam się pacąty.
#
# -
# Input sentence: I chew gum.
# Decoded sentence: Umiem gały się zaważono.
#
# -
# Input sentence: I chuckled.
# Decoded sentence: Znakłem to dobrogi.
#
# -
# Input sentence: I chuckled.
# Decoded sentence: Znakłem to dobrogi.
#
# -
# Input sentence: I disagree.
# Decoded sentence: Zarwolebowałem nam domko.
#
# -
# Input sentence: I doubt it.
# Decoded sentence: Wiezybeł mój placznę.
#
# -
# Input sentence: I drank it.
# Decoded sentence: Poszłam koleksi.
#
# -
# Input sentence: I eat here.
# Decoded sentence: Potrzebałem pięniedz.
#
# -
# Input sentence: I eat meat.
# Decoded sentence: Powinnię obrad.
#
# -
# Input sentence: I envy her.
# Decoded sentence: Nie wiglą mi się czechami.
#
# -
# Input sentence: I exercise.
# Decoded sentence: Ćwieczy mn wieczę.
#
# -
# Input sentence: I got lost.
# Decoded sentence: Zachodzę czekohadzinę.
#
# -
# Input sentence: I got lost.
# Decoded sentence: Zachodzę czekohadzinę.
#
# -
# Input sentence: I guess so.
# Decoded sentence: Czuję się terazybybowany.
#
# -
# Input sentence: I hate Tom.
# Decoded sentence: Nienawidzę poniedziałków.
#
# -
# Input sentence: I hate you.
# Decoded sentence: Nienawidzę posiądujekiponaty.
#
# -
# Input sentence: I hate you.
# Decoded sentence: Nienawidzę posiądujekiponaty.
#
# -
# Input sentence: I have one.
# Decoded sentence: Mam toścha.
#
# -
# Input sentence: I have one.
# Decoded sentence: Mam toścha.
#
# -
# Input sentence: I hear you.
# Decoded sentence: Słyszę cię kocham.
#
# -
# Input sentence: I hear you.
# Decoded sentence: Słyszę cię kocham.
#
# -
# Input sentence: I help him.
# Decoded sentence: Czuję się ty salony.
#
# -
# Input sentence: I know Tom.
# Decoded sentence: Znam tego krzycka.
#
# -
# Input sentence: I know her.
# Decoded sentence: Znam terad uscypka.
#
# -
# Input sentence: I know him.
# Decoded sentence: Znam ten do corni.
#
# -
# Input sentence: I know you.
# Decoded sentence: Znam drawkę.
#
# -
# Input sentence: I like Tom.
# Decoded sentence: Lubię pomoranie.
#
# -
# Input sentence: I like art.
# Decoded sentence: Lubię pomożnie zranię.
#
# -
# Input sentence: I like him.
# Decoded sentence: Lubię kanadyt.
#
# -
# Input sentence: I like tea.
# Decoded sentence: Lubię podróżować.
#
# -
# Input sentence: I like you.
# Decoded sentence: Lubię pomożnie z Tomowi.
#
# -
# Input sentence: I listened.
# Decoded sentence: Przesłegłem woleć.
#
# -
# Input sentence: I love her.
# Decoded sentence: Uwielbiam twój uśmiech.
#
# -
# Input sentence: I love him.
# Decoded sentence: Uwielbiam ten zespół.
#
# -
# Input sentence: I love you.
# Decoded sentence: Uwielbiam twój bajemny.
#
# -
# Input sentence: I love you.
# Decoded sentence: Uwielbiam twój bajemny.
#
# -
# Input sentence: I miss him.
# Decoded sentence: Tęsknię za wojskiem.
#
# -
# Input sentence: I miss you.
# Decoded sentence: Nie jestem kucznekim.
#
# -
# Input sentence: I miss you.
# Decoded sentence: Nie jestem kucznekim.
#
# -
# Input sentence: I need air.
# Decoded sentence: Potrzebuję niezienu.
#
# -
# Input sentence: I need ice.
# Decoded sentence: Potrzebuję nowych spodni.
#
# -
# Input sentence: I need you.
# Decoded sentence: Potrzebuję nowych spoństry.
#
# -
# Input sentence: I objected.
# Decoded sentence: Płakał moie kocham.
#
# -
# Input sentence: I panicked.
# Decoded sentence: Zguszęłam zajęny.
